# %% [markdown]
# # Website A/B Testing - Lab
#
# ## Introduction
#
# In this lab, you'll get another chance to practice your skills at conducting a full A/B test analysis. It will also be a chance to practice your data exploration and processing skills! The scenario you'll be investigating is data collected from the homepage of a music app page for audacity.
#
# ## Objectives
#
# You will be able to:
# * Analyze the data from a website A/B test to draw relevant conclusions
# * Explore and analyze web action data

# %% [markdown]
# ## Exploratory Analysis
#
# Start by loading in the dataset stored in the file 'homepage_actions.csv'. Then conduct an exploratory analysis to get familiar with the data.

# %% [markdown]
# > Hints:
#     * Start investigating the id column:
#         * How many viewers also clicked?
#         * Are there any anomalies with the data; did anyone click who didn't view?
#         * Is there any overlap between the control and experiment groups?
#             * If so, how do you plan to account for this in your experimental design?

# %%
#Your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv(r"C:\Users\user\OneDrive\Desktop\AB Testing'\dsc-website-ab-testing-lab\homepage_actions.csv")

df.head()
# Out:
#                     timestamp      id       group action
# 0  2016-09-24 17:42:27.839496  804196  experiment   view
# 1  2016-09-24 19:19:03.542569  434745  experiment   view
# 2  2016-09-24 19:36:00.944135  507599  experiment   view
# 3  2016-09-24 19:59:02.646620  671993     control   view
# 4  2016-09-24 20:26:14.466886  536734  experiment   view

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8188 entries, 0 to 8187
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  8188 non-null   object
#  1   id         8188 non-null   int64
#  2   group      8188 non-null   object
#  3   action     8188 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 256.0+ KB

# %%
df.shape
# Out:
# (8188, 4)

# %%
df["id"].nunique()
# Out:
# 6328

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#experiment group
exp = df[df["group"] == "experiment"]

#control group
control = df[df["group"] == "control"]

control.head(), exp.head()

control.shape, exp.shape

control["converted"].mean(), exp["converted"].mean()

#plotting the conversion rate for both groups
sns.barplot(x = df["group"], y = df["converted"])

#plotting the number of times each page was visited
sns.countplot(x = df["landing_page"])

#plotting the number of times each page was visited by group
sns.countplot(x = df["landing_page"], hue = df["group"])

#plotting the number of times each page was visited by group
sns.countplot(x = df["group"], hue = df["landing_page"])

#plotting the number of times each page was visited by group
sns.countplot(x = df["group"], hue = df["action"])

#plotting the number of times each page was visited by group
sns.countplot(x = df["action"], hue = df["group"])

#plotting the number of times each page was visited by group
sns.countplot(x = df["action"], hue = df["landing_page"])

#plotting the number of times each page was visited by group
sns.countplot(x = df["landing_page"], hue = df["action"])

#plotting the number of times each page was visited by group
sns.countplot(x = df["action"], hue = df["group"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3802             try:
# -> 3803                 return self._engine.get_loc(casted_key)
#    3804             except KeyError as err:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'converted'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ## Conduct a Statistical Test
#
# Conduct a statistical test to determine whether the experimental homepage was more effective than that of the control group.

# %%
# Your code here
#calculating the observed difference in conversion
obs_diff = exp["converted"].mean() - control["converted"].mean()
obs_diff    #0.0015782389853555567
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3802             try:
# -> 3803                 return self._engine.get_loc(casted_key)
#    3804             except KeyError as err:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'converted'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ## Verifying Results
#
# One sensible formulation of the data to answer the hypothesis test above would be to create a binary variable representing each individual in the experiment and control group. This binary variable would represent whether or not that individual clicked on the homepage; 1 for they did and 0 if they did not.
#
# The variance for the number of successes in a sample of a binomial variable with n observations is given by:
#
# ## $n\bullet p (1-p)$
#
# Given this, perform 3 steps to verify the results of your statistical test:
# 1. Calculate the expected number of clicks for the experiment group, if it had the same click-through rate as that of the control group.
# 2. Calculate the number of standard deviations that the actual number of clicks was from this estimate.
# 3. Finally, calculate a p-value using the normal distribution based on this z-score.

# %% [markdown]
# ### Step 1:
# Calculate the expected number of clicks for the experiment group, if it had the same click-through rate as that of the control group.

# %%
#Your code here

# %% [markdown]
# ### Step 2:
# Calculate the number of standard deviations that the actual number of clicks was from this estimate.

# %%
#Your code here

# %% [markdown]
# ### Step 3:
# Finally, calculate a p-value using the normal distribution based on this z-score.

# %%
#Your code here

# %% [markdown]
# ### Analysis:
#
# Does this result roughly match that of the previous statistical test?
#
# > Comment: **Your analysis here**

# %% [markdown]
# ## Summary
#
# In this lab, you continued to get more practice designing and conducting AB tests. This required additional work preprocessing and formulating the initial problem in a suitable manner. Additionally, you also saw how to verify results, strengthening your knowledge of binomial variables, and reviewing initial statistical concepts of the central limit theorem, standard deviation, z-scores, and their accompanying p-values.
